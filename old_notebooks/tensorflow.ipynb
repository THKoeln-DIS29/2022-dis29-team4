# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [6], line 5
#       3 import matplotlib.pyplot as plt
#       4 from sklearn.model_selection import train_test_split
# ----> 5 from tensorflow.keras.models import Sequential
#       6 from tensorflow.keras.layers import Dense
#       7 from scikeras.wrappers import KerasClassifier
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
data = pd.read_csv('features.csv')
#usecols=['churn_yn','longest_time_between_events', 'event_num', 'enterworld_num', 'levelup_num', 'spendmoney_num', 'itemupgrade_successrate', 'sessions_num'])
data = data.dropna()
data = data.drop(['actor_account_id','survival_time'],axis=1)
data = data.drop(columns=data.columns[0],axis=1)
data
# Out:
#       churn_yn  event_num  enterworld_num  levelup_num  joinparty_num  \
# 1          0.0    39385.0           193.0          5.0          176.0
# 2          0.0    37423.0           176.0         19.0          148.0
# 3          0.0    33900.0           102.0         74.0          104.0
# 4          0.0    49063.0           237.0          0.0          273.0
# 5          1.0     4608.0            28.0          0.0           12.0
# ...        ...        ...             ...          ...            ...
# 4015       1.0    37206.0           176.0         39.0           54.0
# 4016       1.0     4932.0             6.0          5.0            0.0
# 4017       0.0    28439.0           122.0        106.0            4.0
# 4018       0.0   103938.0           894.0          6.0          410.0
# 4019       0.0    63198.0           322.0          0.0          255.0
#
#       spendmoney_num  duel_num  duel_kd  partybattle_num  \
# 1             1358.0      34.0     0.79             37.0
# 2              907.0      10.0     2.33              0.0
# 3              540.0       5.0     0.67              4.0
# 4              470.0       0.0     0.00              0.0
# 5              190.0       0.0     0.00              0.0
# ...              ...       ...      ...              ...
# 4015          2114.0       0.0     0.00              0.0
# 4016            44.0       0.0     0.00              0.0
# 4017           934.0       0.0     0.00              0.0
# 4018          3120.0       0.0     0.00              0.0
# 4019          2481.0       0.0     0.00             39.0
#
#       completechallengetoday_num  ...  guildlevelup_num  level_min  level_max  \
# 1                           12.0  ...               0.0       15.0       50.0
# 2                           12.0  ...               0.0        1.0       50.0
# 3                            2.0  ...               0.0        1.0       50.0
# 4                           36.0  ...               0.0       50.0       50.0
# 5                            2.0  ...               0.0       39.0       50.0
# ...                          ...  ...               ...        ...        ...
# 4015                         0.0  ...               0.0       23.0       50.0
# 4016                         0.0  ...               0.0       50.0       50.0
# 4017                         0.0  ...               0.0        1.0       50.0
# 4018                        65.0  ...               0.0       50.0       50.0
# 4019                         4.0  ...               0.0       50.0       50.0
#
#       class  longest_time_between_events  faction1  faction2  \
# 1       3.0                    253529.85       2.0       0.0
# 2       9.0                    436143.07       1.0       0.0
# 3       3.0                    458000.84       1.0       0.0
# 4       3.0                    161775.37       2.0       0.0
# 5       2.0                   1280471.93       2.0       0.0
# ...     ...                          ...       ...       ...
# 4015    9.0                    332403.55       1.0       0.0
# 4016    3.0                    454534.61       1.0       0.0
# 4017    1.0                    412474.64       2.0       0.0
# 4018    3.0                     70476.16       2.0       0.0
# 4019    5.0                    164034.82       1.0       0.0
#
#       targetaccountid_num  sessions_num  has_smurf_yn
# 1                   170.0         167.0           1.0
# 2                    30.0         152.0           1.0
# 3                    33.0          87.0           1.0
# 4                   123.0         187.0           0.0
# 5                     5.0          28.0           1.0
# ...                   ...           ...           ...
# 4015                 34.0         176.0           1.0
# 4016                  5.0           7.0           1.0
# 4017                 10.0         123.0           1.0
# 4018                115.0         771.0           1.0
# 4019                 77.0         271.0           1.0
#
# [3980 rows x 24 columns]

# %%
X = data.copy()
y = X.pop('churn_yn')
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100)
