# %% [markdown]
# # New Data insight sheet with newly added features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('features.csv')
#usecols=['churn_yn','longest_time_between_events', 'event_num', 'enterworld_num', 'levelup_num', 'spendmoney_num', 'itemupgrade_successrate', 'sessions_num'])
data = data.dropna()
data = data.drop(['actor_account_id','survival_time','churn_yn'],axis=1)
data = data.drop(columns=data.columns[0],axis=1)
data
# Out:
#       event_num  enterworld_num  levelup_num  joinparty_num  spendmoney_num  \
# 1       39385.0           193.0          5.0          176.0          1358.0
# 2       37423.0           176.0         19.0          148.0           907.0
# 3       33900.0           102.0         74.0          104.0           540.0
# 4       49063.0           237.0          0.0          273.0           470.0
# 5        4608.0            28.0          0.0           12.0           190.0
# ...         ...             ...          ...            ...             ...
# 4015    37206.0           176.0         39.0           54.0          2114.0
# 4016     4932.0             6.0          5.0            0.0            44.0
# 4017    28439.0           122.0        106.0            4.0           934.0
# 4018   103938.0           894.0          6.0          410.0          3120.0
# 4019    63198.0           322.0          0.0          255.0          2481.0
#
#       duel_num  duel_kd  partybattle_num  completechallengetoday_num  \
# 1         34.0     0.79             37.0                        12.0
# 2         10.0     2.33              0.0                        12.0
# 3          5.0     0.67              4.0                         2.0
# 4          0.0     0.00              0.0                        36.0
# 5          0.0     0.00              0.0                         2.0
# ...        ...      ...              ...                         ...
# 4015       0.0     0.00              0.0                         0.0
# 4016       0.0     0.00              0.0                         0.0
# 4017       0.0     0.00              0.0                         0.0
# 4018       0.0     0.00              0.0                        65.0
# 4019       0.0     0.00             39.0                         4.0
#
#       completechallengeweek_num  ...  faction2  targetaccountid_num  \
# 1                           0.0  ...       0.0                170.0
# 2                           0.0  ...       0.0                 30.0
# 3                           0.0  ...       0.0                 33.0
# 4                           0.0  ...       0.0                123.0
# 5                           0.0  ...       0.0                  5.0
# ...                         ...  ...       ...                  ...
# 4015                        0.0  ...       0.0                 34.0
# 4016                        0.0  ...       0.0                  5.0
# 4017                        0.0  ...       0.0                 10.0
# 4018                        0.0  ...       0.0                115.0
# 4019                        0.0  ...       0.0                 77.0
#
#       sessions_num   masteryexp  duelpoints_max  partybattlepoints_max  \
# 1            167.0   27624894.0         21594.0                 5420.0
# 2            152.0   30318969.0          1052.0                    0.0
# 3             87.0   16523152.0           275.0                  625.0
# 4            187.0   47490847.0             0.0                    0.0
# 5             28.0   12831466.0             0.0                    0.0
# ...            ...          ...             ...                    ...
# 4015         176.0   25902994.0             0.0                    0.0
# 4016           7.0    5193066.0             0.0                    0.0
# 4017         123.0    6787450.0             0.0                    0.0
# 4018         771.0  191019462.0             0.0                    0.0
# 4019         271.0  197575892.0             0.0                 3348.0
#
#       duel_rating_score_max     money_max  gathering_num  has_smurf_yn
# 1                  144190.0  3.742728e+07           97.0           1.0
# 2                  146146.0  1.733137e+07            6.0           1.0
# 3                  139399.0  2.643581e+07            0.0           1.0
# 4                       0.0  7.976895e+07            0.0           0.0
# 5                       0.0  7.828748e+06            7.0           1.0
# ...                     ...           ...            ...           ...
# 4015                    0.0  1.501839e+09           72.0           1.0
# 4016                    0.0  4.740085e+06            0.0           1.0
# 4017                    0.0  1.507858e+06            0.0           1.0
# 4018                    0.0  6.862637e+07           35.0           1.0
# 4019                    0.0  7.733427e+08          478.0           1.0
#
# [3980 rows x 29 columns]

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(14, 14))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.8})
# Out:
# <AxesSubplot: >

# %%
corr = data.corr()
corr = data.corr()
corr[np.abs(corr)<.8] = 0
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

f, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(corr,mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.8})
# Out:
# <AxesSubplot: >

# %%
data = data.drop(['enterworld_num','buyitemnowmainauction_num','completechallengeweek_num'],axis=1)

# %%
corr = data.corr()
corr = data.corr()
corr[np.abs(corr)<.5] = 0
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

f, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(corr,mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.8})
# Out:
# <AxesSubplot: >

# %%
corr = data.corr()
corr = data.corr()
corr[np.abs(corr)<0.2] = 0
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

f, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(corr,mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.8})
# Out:
# <AxesSubplot: >

# %%
corr = data.corr()
corr[np.abs(corr)>0.5] = 0
mask = np.triu(np.ones_like(corr, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)

f, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(corr,mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.8})
# Out:
# <AxesSubplot: >
